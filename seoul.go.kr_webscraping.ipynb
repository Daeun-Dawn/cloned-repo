# %%
from selenium import webdriver
ch_driver=webdriver.Chrome('C:/Users/user/chromedriver.exe')
ch_driver.get('http://seoul.go.kr/realmnews/in/list.do')

a_path = '//*[@id="content"]/div[2]/div/div[1]/div/a'

news = ch_driver.find_elements_by_xpath(a_path)
news[0].text
# Out:
# '[20906] 「내가 꿈꾸는 서울 : 2040년 서울의 미래상」 슬로건 공모\n2019-01-25 18:29:22 [주택]\n서울시의 2040 서울도시기본계획 수립에 앞서 시민이 바라는 2040년 서울의 모습에 대한 다양한 아이디어를 발굴하고자 2040년 서울의 미래상 슬로건 공모'

# %%
news[0].get_attribute('href')
# Out:
# 'http://news.seoul.go.kr/citybuild/archives/501948'

# %%
# get subject id, post id
subject_id=news[0].find_element_by_class_name('subject').text.split(']')
post_id = int(subject_id[0].strip('['))
subject = subject_id[1].strip()
print(post_id, subject)
# Out:
# 20906 「내가 꿈꾸는 서울 : 2040년 서울의 미래상」 슬로건 공모

# %%
date_cat=news[0].find_element_by_class_name('date').text.split()
post_date_time = (date_cat[0], date_cat[1])
post_cat = date_cat[2].strip('[]')
print(post_date_time, post_cat)
# Out:
# ('2019-01-25', '18:29:22') 주택

# %%
#get abstraction
abs_text = news[0].find_element_by_class_name('txt').text
abs_text
# Out:
# '서울시의 2040 서울도시기본계획 수립에 앞서 시민이 바라는 2040년 서울의 모습에 대한 다양한 아이디어를 발굴하고자 2040년 서울의 미래상 슬로건 공모'

# %%
news_list = []
for item in news:
    # get href
    news_link = item.get_attribute('href')
    # print(news_link)
    
    # get subject, post id
    subject_id = item.find_element_by_class_name('subject').text.split(']')
    post_id = int(subject_id[0].strip('['))
    subject = subject_id[1].strip()
    # print(post_id, subject)
    
    # get post date, time, category
    date_cat = item.find_element_by_class_name('date').text.split()
    post_date_time = (date_cat[0],date_cat[1])
    post_cat = date_cat[2].strip('[]')
    # print(post_date_time, post_cat)
    
    # get abstraction
    abs_text = item.find_element_by_class_name('txt').text
    # print(abs_text)
    
    print(news_link, post_id, subject, post_date_time, post_cat, abs_text, sep='\n')
# Out:
# http://news.seoul.go.kr/citybuild/archives/501948
# 20906
# 「내가 꿈꾸는 서울 : 2040년 서울의 미래상」 슬로건 공모
# ('2019-01-25', '18:29:22')
# 주택
# 서울시의 2040 서울도시기본계획 수립에 앞서 시민이 바라는 2040년 서울의 모습에 대한 다양한 아이디어를 발굴하고자 2040년 서울의 미래상 슬로건 공모
# http://news.seoul.go.kr/env/archives/500739
# 20905
# 미세먼지 비상저감조치, 첫 운행제한 시행일 대비 통행량 33%감소
# ('2019-01-25', '16:53:39')
# 환경
# 서울시는 1.13(일)부터 1.15(화), 사흘간 고농도의 초미세먼지 발생으로 발령기준이 충족되어, ‘비상저감조치’를 발령하였다. 이에 따라 ‘05.12.31일 이전 수도권 등록 총중량 2.5톤이상 경유차에 대하여 1.14(월), 1.15(화) 운행제한을 시행하였다.
# http://news.seoul.go.kr/culture/archives/500726
# 20904
# 서울 외국인관광객, 아시아 '명동', 구·미주 '고궁' 간다…'치안' 만족
# ('2019-01-25', '16:45:07')
# 문화
# 2017년 서울을 여행한 외국인 관광객 중 아시아(중국, 일본, 기타지역) 관광객은 ‘명동’을, 구·미주 관광객은 ‘고궁’을 가장 만족하는 여행 장소로 꼽았다. 만족도 1위 관광 활동 역시 아시아 관광객은 ‘쇼핑’, 구·미주 관광객은 ‘고궁·유적지 방문’이었다. 대부분 여행객들은 서울의 ‘치안’에 대해 높은 만족도를 보였다.
# http://news.seoul.go.kr/citybuild/archives/501917
# 20903
# 서울시, 전 동으로 찾동 확대, 강남구와 찾동 협약체결
# ('2019-01-25', '16:38:32')
# 주택
# 서울시 ‘찾아가는 동주민센터(이하 찾동)’가 전 동으로 확대된다.
# http://news.seoul.go.kr/welfare/archives/504284
# 20902
# 2019년 외국인주민 서울생활 살피미 참여자 모집 안내
# ('2019-01-25', '14:17:34')
# 복지
# ‘2019년 외국인주민 서울생활 살피미’ 참여자 모집
# http://news.seoul.go.kr/welfare/archives/149338
# 20901
# 서울시 여성안심택배 설치장소
# ('2019-01-25', '13:35:41')
# 복지
# 서울시 여성안심택배 설치장소
# http://news.seoul.go.kr/welfare/archives/504274
# 20900
# e편한세상 계양 더프리미어 장애인 특별공급 기관추천 대상자 공고
# ('2019-01-25', '12:55:44')
# 복지
# e편한 계양 기관추천 대상자 공고
# http://news.seoul.go.kr/gov/archives/502426
# 20899
# 제2기 시민인권배심원 선발 결과
# ('2019-01-25', '10:56:18')
# 행정
# 제2기 시민인권배심원 선발결과 발표
# http://news.seoul.go.kr/culture/archives/52631
# 20898
# 복지시설 유니버설디자인 가이드라인
# ('2019-01-25', '10:10:02')
# 문화
# 2010년~2013년까지 제작된 서울시 복지시설 유니비설디자인 가이드라인(24종)입니다.
# http://news.seoul.go.kr/citybuild/archives/501875
# 20897
# 서울시 마을건축가 제도 설명회 개최
# ('2019-01-24', '15:25:51')
# 주택
# 서울시 마을단위의 공간개선 지원, 주민과 함께하는 마을건축가 제도 시행, 설명회 개최 2019. 1. 28.(월)

# %%
# make these to function
def get_content():
    news = ch_driver.find_elements_by_xpath(a_path)
    result = []
    for item in news:
        # get href
        news_link = item.get_attribute('href')
        # print(news_link)

        # get subject, post id
        subject_id = item.find_element_by_class_name('subject').text.split(']')
        post_id = int(subject_id[0].strip('['))
        subject = subject_id[1].strip()
        # print(post_id, subject)

        # get post date, time, category
        date_cat = item.find_element_by_class_name('date').text.split()
        post_date_time = (date_cat[0],date_cat[1])
        post_cat = date_cat[2].strip('[]')
        # print(post_date_time, post_cat)

        # get abstraction
        abs_text = item.find_element_by_class_name('txt').text
        # print(abs_text)

        result.append(
            (news_link, 
             post_id, 
             subject, 
             post_date_time, 
             post_cat, 
             abs_text,))
    return result

# %%
# ch_driver.execute_script('fnPagingMove(2);') => can move to page 2
# so, fnPagingMove(n) => 1 to 10
from time import sleep


# tell driver(브라우저) to wait for 5 secs when certain elements are not available immediately.
ch_driver.implicitly_wait(5)

all_result = []
for i in range(1,10+1):
    # move to page i
    ch_driver.execute_script('fnPagingMove({page_num});'.format(page_num=i))
    # after 1 sec sleep,(인터프리터)
    sleep(1)
    # get all news_content, append to all_result
    all_result.append(get_content())
    
all_result
# Out:
# [[('http://news.seoul.go.kr/citybuild/archives/501948',
#    20906,
#    '「내가 꿈꾸는 서울 : 2040년 서울의 미래상」 슬로건 공모',
#    ('2019-01-25', '18:29:22'),
#    '주택',
#    '서울시의 2040 서울도시기본계획 수립에 앞서 시민이 바라는 2040년 서울의 모습에 대한 다양한 아이디어를 발굴하고자 2040년 서울의 미래상 슬로건 공모'),
#   ('http://news.seoul.go.kr/env/archives/500739',
#    20905,
#    '미세먼지 비상저감조치, 첫 운행제한 시행일 대비 통행량 33%감소',
#    ('2019-01-25', '16:53:39'),
#    '환경',
#    '서울시는 1.13(일)부터 1.15(화), 사흘간 고농도의 초미세먼지 발생으로 발령기준이 충족되어, ‘비상저감조치’를 발령하였다. 이에 따라 ‘05.12.31일 이전 수도권 등록 총중량 2.5톤이상 경유차에 대하여 1.14(월), 1.15(화) 운행제한을 시행하였다.'),
#   ('http://news.seoul.go.kr/culture/archives/500726',
#    20904,
#    "서울 외국인관광객, 아시아 '명동', 구·미주 '고궁' 간다…'치안' 만족",
#    ('2019-01-25', '16:45:07'),
#    '문화',
#    '2017년 서울을 여행한 외국인 관광객 중 아시아(중국, 일본, 기타지역) 관광객은 ‘명동’을, 구·미주 관광객은 ‘고궁’을 가장 만족하는 여행 장소로 꼽았다. 만족도 1위 관광 활동 역시 아시아 관광객은 ‘쇼핑’, 구·미주 관광객은 ‘고궁·유적지 방문’이었다. 대부분 여행객들은 서울의 ‘치안’에 대해 높은 만족도를 보였다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501917',
#    20903,
#    '서울시, 전 동으로 찾동 확대, 강남구와 찾동 협약체결',
#    ('2019-01-25', '16:38:32'),
#    '주택',
#    '서울시 ‘찾아가는 동주민센터(이하 찾동)’가 전 동으로 확대된다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504284',
#    20902,
#    '2019년 외국인주민 서울생활 살피미 참여자 모집 안내',
#    ('2019-01-25', '14:17:34'),
#    '복지',
#    '‘2019년 외국인주민 서울생활 살피미’ 참여자 모집'),
#   ('http://news.seoul.go.kr/welfare/archives/149338',
#    20901,
#    '서울시 여성안심택배 설치장소',
#    ('2019-01-25', '13:35:41'),
#    '복지',
#    '서울시 여성안심택배 설치장소'),
#   ('http://news.seoul.go.kr/welfare/archives/504274',
#    20900,
#    'e편한세상 계양 더프리미어 장애인 특별공급 기관추천 대상자 공고',
#    ('2019-01-25', '12:55:44'),
#    '복지',
#    'e편한 계양 기관추천 대상자 공고'),
#   ('http://news.seoul.go.kr/gov/archives/502426',
#    20899,
#    '제2기 시민인권배심원 선발 결과',
#    ('2019-01-25', '10:56:18'),
#    '행정',
#    '제2기 시민인권배심원 선발결과 발표'),
#   ('http://news.seoul.go.kr/culture/archives/52631',
#    20898,
#    '복지시설 유니버설디자인 가이드라인',
#    ('2019-01-25', '10:10:02'),
#    '문화',
#    '2010년~2013년까지 제작된 서울시 복지시설 유니비설디자인 가이드라인(24종)입니다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501875',
#    20897,
#    '서울시 마을건축가 제도 설명회 개최',
#    ('2019-01-24', '15:25:51'),
#    '주택',
#    '서울시 마을단위의 공간개선 지원, 주민과 함께하는 마을건축가 제도 시행, 설명회 개최 2019. 1. 28.(월)')],
#  [('http://news.seoul.go.kr/welfare/archives/504270',
#    20896,
#    '서울시-㈜아토스터디, 저소득 가구 학생·청년 독서실 이용지원',
#    ('2019-01-24', '14:06:53'),
#    '복지',
#    '서울시가 ㈜아토스터디와 함께 어려운 이웃의 학습 환경 조성을 돕는다. 서울시는 프리미엄 독서실 이용권 나눔 활동 추진을 위하여 오는 25일(금) 오후 2시 시청 4층 지역돌봄복지과장실에서 나눔 전달식을 갖는다.'),
#   ('http://news.seoul.go.kr/gov/archives/502417',
#    20895,
#    "서울시, 안전·교통·나눔.물가.편의 '설날 5대 종합대책'추진",
#    ('2019-01-24', '14:04:30'),
#    '행정',
#    '서울시는 시민들이 안전하고 편안한 설 명절을 보낼 수 있도록 1월 29일(화)부터 7일(목)까지 10일간 안전·교통·나눔·편의·물가 분야를 중심으로 「설날 5대 종합대책」을 시행한다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501872',
#    20894,
#    "서울시, 신축건물에 '미세먼지 95% 필터링' 환기장치 설치 의무화",
#    ('2019-01-24', '14:00:08'),
#    '주택',
#    '서울에서 건물을 신축하거나 증축, 리모델링하는 경우 미세먼지(입자지름 1.6~2.3㎛)를 95% 이상 필터링할 수 있는 ‘기계환기장치’를 의무적으로 설치해야 한다. 또 미세먼지 주범인 질소산화물을 일반 보일러 대비 77% 저감하는 친환경 콘덴싱 보일러도 반드시 설치해야 한다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501869',
#    20893,
#    '서울시, 우리 동네 공간개선 자문·지원 ‘서울형 마을건축가’ 시행',
#    ('2019-01-24', '13:58:39'),
#    '주택',
#    '서울시는 그 간 공공건축 분야에서 가시적 성과를 내고 있는 공공건축가 제도를 확대하여 “서울형 마을건축가” 제도를 2019년부터 본격적으로 시행한다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504264',
#    20892,
#    '청각장애인 인공달팽이관 수술 및 재활지원 계획',
#    ('2019-01-24', '13:33:43'),
#    '복지',
#    '2019년 청각장애인 인공달팽이관 수술 및 재활치료 지원사업계획 공고'),
#   ('http://news.seoul.go.kr/economy/archives/501365',
#    20891,
#    '설 제수용품 최대 50% 할인, 전통시장으로 장보러 오세요',
#    ('2019-01-24', '11:26:49'),
#    '경제',
#    '- 1.24.(목)~2.3.(일), 서울시 122개 전통시장 제수용품 및 농산물 직거래장터\n\n- 50~10% 할인판매, 5만원 이상 구매 또는 제로페이 결제시 다양한 경품 제공\n\n- 떡메치기, 윷놀이 등 즐길거리 풍성, 독거노인·저소득층 위한 떡국 나눔행사 진행\n\n- 주차난 해소 위해 115개 전통시장 주변도로 2시간 무료 주·정차 임시 허용'),
#   ('http://news.seoul.go.kr/economy/archives/501369',
#    20890,
#    '2019년 설 명절기간 전통시장 주변도로 주차 허용구간 안내',
#    ('2019-01-24', '11:13:34'),
#    '경제',
#    '2019년 설 명절기간 전통시장 주변도로 주차허용 안내'),
#   ('http://news.seoul.go.kr/economy/archives/501374',
#    20889,
#    '올해 서울 설 차례상차림, 전통시장이 대형마트보다 20%싸다.',
#    ('2019-01-24', '10:11:21'),
#    '경제',
#    '- 서울시농수산식품공사, 전통시장 50곳·대형마트 25곳·가락시장(가락몰) 설 차례상차림 비용 조사결과 발표'),
#   ('http://news.seoul.go.kr/citybuild/archives/501854',
#    20888,
#    '서울시, 세운상가 일대 도심전통산업과 오래된 가게(老鋪) 보존 추진',
#    ('2019-01-23', '15:00:39'),
#    '주택',
#    '서울시가 지역의 역사와 정체성을 담고 있는 세운상가 일대 도심전통산업, 생활유산인 을지면옥 등 오래된 가게(老鋪)에 대한 보존을 추진한다.'),
#   ('http://news.seoul.go.kr/env/archives/500735',
#    20887,
#    '서울시, 4년여 걸쳐 ‘테마산책길’ 150개소 발굴... 4권 책으로 발간',
#    ('2019-01-23', '14:59:01'),
#    '환경',
#    '지난 2016년 첫 권 발행을 시작으로 4년간(’16년~’19년), 서울의 구석구석 아름답고 다양한 산책길의 매력을 알린 ‘서울, 테마산책길’의 마지막 4권이 발간되며, 그간 많은 시민들의 관심과 사랑을 받던 산책길 책자의 시리즈가 완간된다.')],
#  [('http://news.seoul.go.kr/gov/archives/502407',
#    20886,
#    '서울시, 2018년 행정안전부 민원서비스 종합평가 최우수 기관 선정',
#    ('2019-01-23', '14:56:24'),
#    '행정',
#    '서울시가 행정안전부와 국민권익위원회가 공동으로 실시한 ‘2018년 민원서비스 종합평가’에서 17개 시·도 광역자치단체 가운데 ‘가’ 등급을 받아 최우수 기관으로 선정됐다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504254',
#    20885,
#    '서울시 인터넷 시민감시단, 성매매 광고 5만2천여건 잡아',
#    ('2019-01-23', '14:54:10'),
#    '복지',
#    '일상에서 자주 마주하게 되는 성매매 알선·광고, 음란물 등 불법·유해 정보를 그냥 지나치지 않고 모니터링해 적극적으로 신고하는 ‘서울시 인터넷 시민감시단’. 이들은 지난 한 해 동안 인터넷 및 스마트폰 어플리케이션(App) 상의 성매매 광고 등 불법·유해 정보 5만2,677건을 모니터링했다.'),
#   ('http://news.seoul.go.kr/culture/archives/500718',
#    20884,
#    '서울광장 스케이트장, 대기질 악화로 오전 11시부터 운영 중단',
#    ('2019-01-23', '14:47:26'),
#    '문화',
#    '서울시는 금일 ‘초미세먼지 주의보’가 발령(오전 11시)됨에 따라, 이용객의 건강과 안전을 위해 오전 11시부터 서울광장 스케이트장 운영을 중단한다.'),
#   ('http://news.seoul.go.kr/economy/archives/501360',
#    20883,
#    '2019년 상반기 서울시 기술교육원 직업교육훈련생 모집',
#    ('2019-01-23', '11:29:02'),
#    '경제',
#    '서울특별시에서는 2019년도 상반기 서울특별시 기술교육원 직업교육훈련생을 다음과 같이 모집합니다.'),
#   ('http://news.seoul.go.kr/gov/archives/502369',
#    20882,
#    '2019년 상반기 서울시 기술교육원 직업교육훈련생 추가 모집 공고',
#    ('2019-01-23', '11:04:28'),
#    '행정',
#    '2019년 상반기 서울시 기술교육원 직업교육훈련생 모집'),
#   ('http://news.seoul.go.kr/economy/archives/501318',
#    20881,
#    '서울형 뉴딜일자리 (민생호민관) 사업 참여자 모집 공고',
#    ('2019-01-23', '10:10:39'),
#    '경제',
#    '민생침해 예방과 구제 등 다양한 활동을 하는 민생호민관(분야 1: 일반민생침해 / 분야 2: 공정거래)을 1.28(월)~2.1(금) 까지 모집합니다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504231',
#    20880,
#    '2019년 서울시 인터넷 시민 감시단 모집',
#    ('2019-01-22', '18:06:57'),
#    '복지',
#    '2019년 서울시 인터넷 시민 감시단 모집'),
#   ('http://news.seoul.go.kr/safe/archives/500473',
#    20879,
#    "서울시 '119 영상 신고 시스템' 도입... 실시간 대응력 높인다",
#    ('2019-01-22', '16:19:44'),
#    '안전',
#    '올 해부터 ‘119영상 신고 접수시스템’이 새로 도입된다. 화재·구조·구급상황 발생시 119로 신고하면 영상통화로 신고자의 현장상황에 맞는 응급처치 지도 등 신속한 조치로 황금시간 달성률을 한 단계 더 끌어 올릴 수 있을 것으로 기대된다. 한편 지난 해 12월부터 119 구급 신고자에게는 구급차 실시간 위치 및 구급대원 연락처 등 출동정보를 문자로 전송해 주는 서비스를 실시하고 있다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501850',
#    20878,
#    '서울시 플랫폼창동61이 배출한 뮤지션, 해외진출 줄 잇는다',
#    ('2019-01-22', '16:15:15'),
#    '주택',
#    '2016년 서울시가 문을 연 복합문화공간 ‘플랫폼창동61’의 입주·협력 뮤지션들이 세계 최대 음악축제인 영국의 ‘글래스톤베리’, 미국 캘리포니아의 ‘코첼라’ 등 해외 유명 음악 페스티벌로부터 잇따른 초청을 받으며 글로벌 무대에서 주목받는 팀으로 성장하고 있다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504221',
#    20877,
#    '교육급여 받는 학생들 대입 국가장학금 신청하세요',
#    ('2019-01-22', '09:33:20'),
#    '복지',
#    '#교육급여, #국가장학금, #한국장학재단, #교육부')],
#  [('http://news.seoul.go.kr/env/archives/500718',
#    20876,
#    '기후변화 협치자문관 공개모집(~2.7)',
#    ('2019-01-22', '09:08:42'),
#    '환경',
#    '기후변화 협치 자문관 공개 모집'),
#   ('http://news.seoul.go.kr/citybuild/archives/501817',
#    20875,
#    "서울시, 새로운 광화문 '21년 시민 품으로… 국제설계공모 당선작 공개",
#    ('2019-01-21', '14:23:36'),
#    '주택',
#    '광화문광장이 오는 2021년 차 중심의 거대한 중앙분리대라는 오명을 벗고 역사성을 간직한 국가 상징광장이자 열린 일상의 민주공간으로 탈바꿈, 시민 품으로 돌아온다.'),
#   ('http://news.seoul.go.kr/env/archives/500707',
#    20874,
#    '서울시, 설 명절 과대포장 집중 단속 (1.21~2.1)',
#    ('2019-01-21', '13:26:32'),
#    '환경',
#    '21일(월)부터 2주간 설 선물 과대포장 집중 점검, 과태료 최대 300만원'),
#   ('http://news.seoul.go.kr/welfare/archives/504214',
#    20873,
#    "서울시, 10년 간 저소득 장애인 1,098가구 '무료 맞춤형 집수리'",
#    ('2019-01-21', '13:22:48'),
#    '복지',
#    '장애인 개개인의 거주환경, 장애유형, 행동패턴을 종합적으로 고려해 무료로 맞춤형 집수리를 해주는 서울시의 ‘저소득장애인 맞춤형 집수리 사업’이 시행 10년이 됐다. 한국장애인개발원과 함께 지난 10년 간 총 1,098가구에 집수리를 지원해 장애인의 주거 편의를 높였다.'),
#   ('http://news.seoul.go.kr/economy/archives/501313',
#    20872,
#    "설 명절 전후 허위·과장광고 기승… 서울시, '불법대부업 피해주의보' 발령",
#    ('2019-01-21', '13:22:22'),
#    '경제',
#    '서울시, 21일(월)부터 2달간 불법대부광고 민원다발업체 116개소 집중 단속'),
#   ('http://news.seoul.go.kr/economy/archives/501306',
#    20871,
#    '서울시, 여의도에 제 2 핀테크랩 조성…투자유치·해외진출 지원',
#    ('2019-01-21', '13:01:22'),
#    '경제',
#    '- 시,급증하는 수요 대응 위해 마포 핀테크랩(‘18 개관)에 이어 추가 공간 확충\n- ‘20년 개강 목표로 금융대학원, 핀테크 아카데미 개설 등 전문 인재양성 도모\n- 해외 금융사의 유치 위해 초기 사무공간과 네트워킹 지원, 서울투자설명회 진행'),
#   ('http://news.seoul.go.kr/citybuild/archives/501804',
#    20870,
#    '용산전자상가 도시재생 소식지 창간호 발행',
#    ('2019-01-21', '10:47:26'),
#    '주택',
#    '용산전자상가 도시재생 소식지 창간호 발행'),
#   ('http://news.seoul.go.kr/economy/archives/501301',
#    20869,
#    '서울시, 월 최대 215만원‘취업디딤돌’뉴딜일자리 5,450여명 선발',
#    ('2019-01-21', '09:44:37'),
#    '경제',
#    '- 시, 1.21.(월)~2.1.(금), 경제·문화·복지 등 129개 사업참여자 1,005명 우선 선발\n- 서울형 생활임금으로 월 최대 215만원 지급, 공휴일 유급휴가 보장 등 근로조건 개선\n- 최대 23개월 ‘일경험’ 쌓으며 맞춤형 지원을 통해 참여자 역량 키우고 기업 취업 연계'),
#   ('http://news.seoul.go.kr/economy/archives/501293',
#    20868,
#    '서울시, 3·1운동 100주년 창작 기념곡 공모…문화 콘텐츠로 역사 알린다.',
#    ('2019-01-21', '09:06:47'),
#    '경제',
#    '- 민족의 자긍심을 드높일 “오등(吾等)은 자(玆)에 아음악(我音樂)” 공모전 개최\n- 3·1운동을 현대적, 대중적으로 알릴 수 있는 자유로운 주제와 장르의 창작곡 모집\n- 1.21(월)~2.20(수) 공모, 8곡 음원 녹음 및 우수작 4곡 음원 제작비 지원'),
#   ('http://news.seoul.go.kr/welfare/archives/504208',
#    20867,
#    '쌍용 더플래티넘 부평 장애인 특별공급 서울시 기관추천 대상자 공고',
#    ('2019-01-18', '14:37:19'),
#    '복지',
#    '쌍용 더플래티넘 부평 기관추천 대상자 공고')],
#  [('http://news.seoul.go.kr/gov/archives/502312',
#    20866,
#    '서울시, 정보화사업에 2,306억원 투자해 경제 성장 모멘텀 창출',
#    ('2019-01-18', '10:36:43'),
#    '행정',
#    '846개 사업 민간기업 참여로 2,928개 청년일자리 창출'),
#   ('http://news.seoul.go.kr/culture/archives/500705',
#    20865,
#    "서울시 제작 웹드라마 '풍경', 18일(금) 네이버TV, 라쿠텐비키 동시 첫 공개",
#    ('2019-01-18', '10:35:32'),
#    '문화',
#    '서울시 제작 웹드라마 ‘풍경(風磬)’이 오는 18일(금), 정오(낮12시)에 ‘네이버TV’와 월드와이드 동영상플랫폼 ‘라쿠텐비키’에서 동시에 공개된다. 지난 2017년, 서울시 「서울스토리 드라마대본 공모전」당선작인 ‘풍경(風磬)’은 서울을 소재로 하는 시민공모작을 웹드라마화한 첫 번째 사례이다.'),
#   ('http://news.seoul.go.kr/traffic/archives/500521',
#    20864,
#    "서울시, 6월 상암에 세계 최초 '5G 자율주행 테스트베드' 미래교통 선도",
#    ('2019-01-18', '10:33:19'),
#    '교통',
#    '울시가 오는 6월 상암 DMC에 세계 최초의 ‘5G 융합 자율주행 테스트베드’를 구축 완료한다. 일반도로에서 5G, 차량통신기술(V2X)로 자율주행을 지원하는 세계 유일의 테스트베드다. 이르면 6월 중 5G 자율주행버스의 시범운행도 시작된다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501792',
#    20863,
#    "서울시, 안전관리 사각지대 '민간 건축공사장' 인허가 전 단계 혁신",
#    ('2019-01-18', '10:32:46'),
#    '주택',
#    '건축주 중심 일사천리식 인허가 → 공사 전(全) 단계별로 ‘시민안전’ 최우선, 공공역할 강화'),
#   ('http://news.seoul.go.kr/economy/archives/501286',
#    20862,
#    '서울특별시 시간선택제 임기제공무원 채용시험 최종합격자 공고',
#    ('2019-01-18', '09:43:01'),
#    '경제',
#    '서울특별시 시간선택제 임기제공무원 채용시험 최종합격자 공고'),
#   ('http://news.seoul.go.kr/gov/archives/111984',
#    20861,
#    '서울시 기부금품 모집등록 제도 안내',
#    ('2019-01-18', '09:25:35'),
#    '행정',
#    '서울시 기부금품 모집등록 제도 안내'),
#   ('http://news.seoul.go.kr/safe/archives/500443',
#    20860,
#    '2019년도 민방위의 날 훈련 일정 안내',
#    ('2019-01-17', '17:01:30'),
#    '안전',
#    '2019년도 민방위의 날 훈련 일정입니다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504167',
#    20859,
#    '2019 서울여성공예센터 신규입주기업 모집',
#    ('2019-01-17', '15:32:59'),
#    '복지',
#    '□ 1월 17일(목)부터 29일(화)까지 13일간 서울여성공예센터 창업실에 입주할 신규입주기업을 모집한다. 공예 기반 사업 아이템을 보유하고 적극적인 사업 지속 수행 의지를 가진 여성(예비)공예창업가 중 사업장 주소지 혹은 거주지가 서울인 여성이면 지원가능하다.'),
#   ('http://news.seoul.go.kr/economy/archives/501275',
#    20858,
#    '서울시, 올해 1,300여명에 건강한 농산물 생산 돕는 ‘농업인 실용교육’',
#    ('2019-01-17', '14:33:34'),
#    '경제',
#    '서울시는 서울농업인 330명을 대상으로 환경 친화적인 농산물 생산을 돕기 위해 ‘농업인 실용교육’을 1월 18일(금)부터 2월 12일(화)까지 진행한다고 밝혔다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501780',
#    20857,
#    "서울시, 화곡역에 '역세권 청년주택' 57세대 공급",
#    ('2019-01-17', '14:22:35'),
#    '주택',
#    "지하철 5호선 화곡역 인근에 오는 '21년 ‘역세권 청년주택’이 들어선다. 입면디자인 특화 계획을 통해 화곡역 역세권의 도시경관을 다채롭게 만들 예정이다.")],
#  [('http://news.seoul.go.kr/citybuild/archives/501777',
#    20856,
#    "서울시, 건설 폐기물·토사 무단반출 원천차단 '앱' 사용 의무화",
#    ('2019-01-17', '14:20:00'),
#    '주택',
#    '건설현장에서 나오는 폐기물은 지정된 중간처리업체에서 처리해야 하지만 공사 현장과 가까운 업체에 임의 반출하거나 불법 투기해 환경오염을 일으키는 경우가 존재했다. 공사 현장에서 발생한 토사(암)도 지정된 곳이 아닌 가까운 사토장에 임의 반출하거나 다른 공사현장에 되파는 등 무단 반출 사례가 있지만 폐기물·토사 반출 관리는 대부분 수기로 이뤄지고 있어 무단 반출 진위 여부를 파악하기 어려운 실정이다.'),
#   ('http://news.seoul.go.kr/economy/archives/501268',
#    20855,
#    '서울시, 올해 1,300여명에 건강한 농산물 생산 돕는 ‘농업인 실용교육’',
#    ('2019-01-17', '10:45:58'),
#    '경제',
#    '- 서울특별시농업기술센터, 올해 27회 1,350명 농업인 교육 추진 계획 밝혀\n- 농업인 300명 대상 농한기 활용 올해 전면시행 농약허용물질관리제도 등 교육'),
#   ('http://news.seoul.go.kr/economy/archives/501265',
#    20854,
#    '서울시, 가맹점 창업 필수 확인서‘가맹본부 정보공개서’등록 개시',
#    ('2019-01-16', '16:48:30'),
#    '경제',
#    '올해 1월 1일부터 길게는 수개월씩 소요되던 가맹본부의 정보공개서 등록업무를 공정위로부터 서울, 인천, 경기 등의 3개 지자체가 이양 받아 분담 처리한다. 타 지역에 비해 가맹본부 수가 많은 서울지역의 업체들은 서울시가 전담해서 등록업무를 추진함에 따라 좀 더 빠른 서비스를 받을 수 있게 된다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504161',
#    20853,
#    '‘핸드허그 좋아요’ 서울시, 굿위드어스와 저소득 한부모.조손가정 청소년 지원',
#    ('2019-01-16', '16:42:12'),
#    '복지',
#    '서울시는 사단법인 굿위드어스와 함께 공동체의식 회복과 나눔문화 확산을 위해 전개한 제2회 ‘핸드허그 캠페인’ 후원금·품 3억 5,500만 원을 저소득 한부모 가정과 조손 가정 청소년을 위해 기부한다고 밝혔다.'),
#   ('http://news.seoul.go.kr/traffic/archives/500508',
#    20852,
#    '서울시, 위험천만‘불법 개조 자동차’고강도 합동단속',
#    ('2019-01-16', '16:38:15'),
#    '교통',
#    '서울시가 시민 안전을 위협하고 차량 운행에 불편을 주는 불법 전조등, 굉음을 발생하는 소음기 등 불법 개조 자동차 근절에 나선다.'),
#   ('http://news.seoul.go.kr/gov/archives/502269',
#    20851,
#    '제2기 시민인권배심원 공개 선발 알림',
#    ('2019-01-16', '14:33:29'),
#    '행정',
#    '시민인권배심원 공개 선발'),
#   ('http://news.seoul.go.kr/gov/archives/502245',
#    20850,
#    '재단법인 서울장학재단 비상임 임원 초빙 공고',
#    ('2019-01-15', '17:00:35'),
#    '행정',
#    '(재) 서울장학재단에서는 공평한 교육기회 제공을 통해 서울의 우수한 인재를 발굴.육성하는 장학사업을 함께 이끌어갈 비상임 임원을 공개 초빙합니다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501735',
#    20849,
#    '서울시 및 자치구 도시계획 관련 주요 열람공고 및 결정고시(1월 1~2주)',
#    ('2019-01-15', '16:40:08'),
#    '주택',
#    '서울시 및 자치구 도시계획 관련 주요 열람공고 및 결정고시(1월 1~2주)'),
#   ('http://news.seoul.go.kr/welfare/archives/504150',
#    20848,
#    '서울시, 여성안심택배 주유소로 확대…현대오일뱅크와 업무협약',
#    ('2019-01-15', '14:34:55'),
#    '복지',
#    '그동안 동주민센터, 교회, 은행 등에서만 이용할 수 있던 서울시 여성안심택배를 주유소에서도 이용할 수 있게 됐다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501725',
#    20847,
#    "'새로운 광화문광장 조성 설계공모 심사위원' 아드리안 구즈 강연회 개최",
#    ('2019-01-15', '14:32:18'),
#    '주택',
#    "'새로운 광화문광장 조성 설계공모 심사위원'이자 세계적인 조경전문가 아드리안 구즈 강연회 개최")],
#  [('http://news.seoul.go.kr/env/archives/500692',
#    20846,
#    '서울하수도과학관, 연령대 맞춤형 교육수혜자 연4만 명으로 확대',
#    ('2019-01-15', '14:29:24'),
#    '환경',
#    '서울하수도과학관이 2019년을 맞이하여 교육프로그램 및 각종 문화행사를 새롭게 확대 개편한다.'),
#   ('http://news.seoul.go.kr/env/archives/500689',
#    20845,
#    '서울시, 시민 100명 ‘산사태현장예방단’ 운영해 산사태 예방 총력',
#    ('2019-01-15', '14:24:16'),
#    '환경',
#    '최근 기후변화의 영향에 따라 봄 부터 가을까지 집중호우가 잦아지며 산사태로 인한 피해 우려가 높아지는 가운데, 서울시가 100명의 시민과 함께 서울시의 산사태 예방을 적극 추진한다.'),
#   ('http://news.seoul.go.kr/citybuild/archives/501728',
#    20844,
#    '서울시, 서울시립대학교 미래융합관 설계공모 당선작 발표',
#    ('2019-01-15', '14:17:05'),
#    '주택',
#    '서울시는 서울시립대학교 내에 이공계학부의 교육, 연구를 위한 전용공간인 ‘서울시립대학교 미래융합관’ 건립을 위하여 ’18.11월부터 설계 공모를 진행한 결과 건축사사무소 오드투에이(대표 정은주) 작품을 최종 당선작으로 선정하였다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504119',
#    20843,
#    '홍역 예방 및 관리',
#    ('2019-01-15', '13:44:07'),
#    '복지',
#    '홍역, 기침예절'),
#   ('http://news.seoul.go.kr/welfare/archives/504107',
#    20842,
#    '검단신도시 센트럴 푸르지오 AB16BL 장애인 특별공급 서울시 기관추천 안내',
#    ('2019-01-14', '21:51:55'),
#    '복지',
#    '검단 신도시 센트럴 푸르지오 기관추천 안내'),
#   ('http://news.seoul.go.kr/welfare/archives/504100',
#    20841,
#    '‘부양의무자 기준 완화·돌봄SOS센터 신설’ 서울복지가 더 탄탄해집니다',
#    ('2019-01-14', '14:46:41'),
#    '복지',
#    '서울시가 2019년 서울형 기초보장 부양의무자 기준 완화, 돌봄SOS센터 신설 및 서울형 긴급복지 확대 지원 등으로 취약계층·어르신·장애인에 대한 공공지원 문턱을 낮추고 보다 탄탄한 복지 기반을 구축하겠다고 밝혔다.'),
#   ('http://news.seoul.go.kr/safe/archives/500396',
#    20840,
#    '서울시, 1만2000여개 제설함 관리…쓰레기 버리지 마세요!',
#    ('2019-01-14', '14:40:55'),
#    '안전',
#    '서울시는 겨울철 제설 취약지역에 설치된 제설함 12,679개에 대한 일제점검을 실시했으며, 강설 전후 제설제와 제설도구가 잘 비치되어 있는지 꼼꼼히 살피고 부족한 곳은 수시로 보충하는 등 제설함 관리를 강화한다고 밝혔다.'),
#   ('http://news.seoul.go.kr/economy/archives/501140',
#    20839,
#    '서울시, 개정 산업안전보건법 시행 선제적으로 대비한다',
#    ('2019-01-14', '14:39:51'),
#    '경제',
#    '산업안전 전담조직 신설해 체계적 대책 추진과 예방책 마련, 노동안전조사관제 도입'),
#   ('http://news.seoul.go.kr/traffic/archives/500504',
#    20838,
#    '서울시-서울경찰청 공동대응 5년… ‘18년 교통사고사망자 역대 최저',
#    ('2019-01-14', '14:35:11'),
#    '교통',
#    '’18년 서울시내 자동차 1만 대당 교통사고 사망자 수 0.96명을 기록했다. 자동차 1만대당 사망자수는 최근 10년간 1.1명~1.5명으로 1명대 초반을 맴돌다가 처음으로 1명 이하로 내려갔다.'),
#   ('http://news.seoul.go.kr/economy/archives/501136',
#    20837,
#    '서울시, 소상공인 의류·구두·장신구 안전검사비용 100% 지원',
#    ('2019-01-14', '14:32:12'),
#    '경제',
#    '가방 등 가정용 섬유제품, 가죽제품, 반지 등 접촉성 금속장신구 75→100% 지원 확대')],
#  [('http://news.seoul.go.kr/citybuild/archives/501676',
#    20836,
#    "서울시, '보증금지원형 장기안심주택' 올해 2천호... 40% 신혼부부 특별공급",
#    ('2019-01-14', '14:31:40'),
#    '주택',
#    '서울시는 무주택 서민들의 주거비 부담을 덜어주기 위해 전월세보증금의 30%(최대 4,500만원, 신혼부부 6,000만원)를 서울시 재원으로 지원하는 ‘보증금 지원형 장기안심주택’ 을 올해 2,000호 공급한다고 밝혔다.'),
#   ('http://news.seoul.go.kr/culture/archives/500687',
#    20835,
#    '서울광장 스케이트장, 대기질 악화로 1월 14일(월) 全 회차 운영 중단',
#    ('2019-01-14', '14:24:28'),
#    '문화',
#    '‘수도권형 비상저감조치’ 발령으로 인한 운영 중단'),
#   ('http://news.seoul.go.kr/gov/archives/502232',
#    20834,
#    '2019년 공기업하수도특별회계 예산서',
#    ('2019-01-14', '13:50:24'),
#    '행정',
#    '2019년도 공기업하수도특별회계 예산서'),
#   ('http://news.seoul.go.kr/gov/archives/502236',
#    20833,
#    '서울시 기부금품 모집등록 제도 안내',
#    ('2019-01-14', '13:21:07'),
#    '행정',
#    '2019년도 서울시 기부금품 모집제도 등록 안내'),
#   ('http://news.seoul.go.kr/citybuild/archives/501645',
#    20832,
#    '온동네 소식지(2019년 1월호)',
#    ('2019-01-13', '13:32:10'),
#    '주택',
#    '온동네 1월호'),
#   ('http://news.seoul.go.kr/culture/archives/500677',
#    20831,
#    '(1/19) 재능나눔콘서트',
#    ('2019-01-13', '12:40:26'),
#    '문화',
#    '재능나눔콘서트, 서울역사박물관'),
#   ('http://news.seoul.go.kr/citybuild/archives/501629',
#    20830,
#    "서울시, 태릉입구역에 노원구 1호 '역세권 청년주택' 270세대",
#    ('2019-01-11', '16:20:19'),
#    '주택',
#    "지하철 6·7호선 태릉입구역 인근에 오는 '21년 ‘역세권 청년주택’이 들어선다. 노원구에 건립이 결정된 첫 번째 역세권 청년주택이다."),
#   ('http://news.seoul.go.kr/citybuild/archives/501626',
#    20829,
#    "서울시, 천호역 인근 주유소 부지 '역세권 청년주택' 탈바꿈",
#    ('2019-01-11', '16:16:45'),
#    '주택',
#    "서울시, 천호역 인근 주유소 부지 '역세권 청년주택' 탈바꿈"),
#   ('http://news.seoul.go.kr/env/archives/500679',
#    20828,
#    '서울시, 민간단체 수질보전활동 지원사업 공모',
#    ('2019-01-11', '16:02:19'),
#    '환경',
#    '서울시는 한강 및 중랑천, 탄천, 안양천 등 시민생활 가까이에 흐르는 하천을 맑고 깨끗한 생태공간으로 가꾸기 위하여 하천수질 보전활동을 추진할 민간환경단체를 공개 모집한다고 밝혔다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504089',
#    20827,
#    '편의점 도시락 전자레인지 조리하면 세균수 크게 감소',
#    ('2019-01-11', '15:58:09'),
#    '복지',
#    '편의점 도시락을 전자레인지에 조리하면 위생지표세균수가 전자레인지 조리 전보다 77%에서 최고 99.999%까지 현저히 감소하는 것으로 조사됐다.')],
#  [('http://news.seoul.go.kr/safe/archives/500388',
#    20826,
#    '(안전, 기반시설 분야) 2019년 서울특별시 용역 설명회',
#    ('2019-01-11', '15:55:46'),
#    '안전',
#    '2019년도 서울시 발주 예정인 기반시설·소방·산지방재 분야의 학술·기술 용역설명회 개최'),
#   ('http://news.seoul.go.kr/economy/archives/501130',
#    20825,
#    '[세모편지 122호',
#    ('2019-01-11', '14:18:02'),
#    '경제',
#    '세모편지122호'),
#   ('http://news.seoul.go.kr/welfare/archives/504082',
#    20824,
#    'e편한세상 계양 더프리미어 장애인 특별공급 기관추천 안내',
#    ('2019-01-11', '13:34:50'),
#    '복지',
#    '계양 e편한세상 기관추천 안내'),
#   ('http://news.seoul.go.kr/economy/archives/501078',
#    20823,
#    '2019년 함께서울 친환경농장 접수 안내',
#    ('2019-01-11', '13:02:22'),
#    '경제',
#    '모집기간 : 2019년 2월 1일(금) 09:00 ~ 3월 31일(일) (인터넷 선착순 모집)\n신청대상 : 서울시민 및 서울소재 기관, 단체'),
#   ('http://news.seoul.go.kr/welfare/archives/504075',
#    20822,
#    '서울형 뉴딜일자리 시민사회활동가양성프로젝트 참여자 모집공고',
#    ('2019-01-11', '10:00:53'),
#    '복지',
#    '「서울형 뉴딜일자리 시민사회 활동가 양성 프로젝트 」참여자 모집 공고'),
#   ('http://news.seoul.go.kr/economy/archives/501108',
#    20821,
#    '[서울창업허브, 시립대 스마트창작터',
#    ('2019-01-11', '09:15:22'),
#    '경제',
#    '* 행사일시 및 장소 : 2019년 1월 30일/서울창업허브 10층 대강당'),
#   ('http://news.seoul.go.kr/gov/archives/502187',
#    20820,
#    '서울시민 공유도시 희망아이템 1위 ‘주차’, 인기정책은 ‘따릉이’',
#    ('2019-01-10', '14:33:08'),
#    '행정',
#    '서울시민 공유도시 희망아이템 1위 ‘주차’, 인기정책은 ‘따릉이’'),
#   ('http://news.seoul.go.kr/gov/archives/502184',
#    20819,
#    "서울시, 민선7기 청사진 ｢서울시정 4개년('19.~'22.) 계획｣ 발표",
#    ('2019-01-10', '14:29:48'),
#    '행정',
#    "서울시, 민선7기 청사진 ｢서울시정 4개년('19.~'22.) 계획｣ 발표"),
#   ('http://news.seoul.go.kr/welfare/archives/504061',
#    20818,
#    '서울시, 올해 성평등기금 9억원... 24일까지 접수',
#    ('2019-01-10', '14:09:40'),
#    '복지',
#    '서울시는 시민단체와의 공동협력을 통해 여성의 사회참여 확대와 권익 향상을 위한 정책을 추진하는 ‘2019년 성평등기금 공모사업’을 실시한다. 신청은 1월 24일(목)까지 접수 가능하다.'),
#   ('http://news.seoul.go.kr/welfare/archives/504058',
#    20817,
#    '서울시, 새마을금고와 함께 ‘좀도리 운동’ 성금 2억 원 기부',
#    ('2019-01-10', '14:05:38'),
#    '복지',
#    '서울시, 새마을금고와 함께 ‘좀도리 운동’ 성금 2억 원 기부')],
#  [('http://news.seoul.go.kr/welfare/archives/504055',
#    20816,
#    '서울시, 낙인감 없는 카카오톡 선물하기로 나눔의 새 지평 연다',
#    ('2019-01-10', '13:59:52'),
#    '복지',
#    '서울시, 낙인감 없는 카카오톡 선물하기로 나눔의 새 지평 연다'),
#   ('http://news.seoul.go.kr/gov/archives/502167',
#    20815,
#    '2018년 귀속 연말정산 서류제출 안내(서울시 행정국 소속직원 대상)',
#    ('2019-01-10', '11:18:31'),
#    '행정',
#    '2018년 연말정산'),
#   ('http://news.seoul.go.kr/economy/archives/501092',
#    20814,
#    'SBA,『2019 미래를 여는 새로운 직업』 발간',
#    ('2019-01-10', '09:29:09'),
#    '경제',
#    '- 손에 잡히는 일자리가 있는 기업사례 중심 유망 신직업 일자리 수록\n- 기술과 혁신, 창의와 비즈니스, 인간과 행복의 3개 영역에 대해 AR\nVR, 모빌리티, 정보보안, 헬스케어 등 11개의 미래직업 키워드 제안'),
#   ('http://news.seoul.go.kr/citybuild/archives/501567',
#    20813,
#    '도시관리계획(마천 지구단위계획) 결정(변경)(안) 열람공고',
#    ('2019-01-10', '09:20:49'),
#    '주택',
#    '도시관리계획(마천 지구단위계획) 결정(변경)(안) 열람공고'),
#   ('http://news.seoul.go.kr/economy/archives/501088',
#    20812,
#    '서울시, 소상공인·소기업에 저금리 우량자금 1조 5천억원 융자지원',
#    ('2019-01-10', '09:08:04'),
#    '경제',
#    '- 서울시 ‘19년 중소기업육성자금 ‘18년보다 약 5천억원 대폭 증가한 1조 5천억 지원\n- 시중은행 대출금리 상승불구, 낮은 대출금리 유지해 소공인,자영업자에 필요자금 적기지원'),
#   ('http://news.seoul.go.kr/economy/archives/501069',
#    20811,
#    '서울창업디딤터 STATION:D 참여 기관 모집 공고',
#    ('2019-01-09', '17:06:53'),
#    '경제',
#    '모집기간: 2019년 1월 9일(수) ~ 2019년 1월 18일(금) 15:00까지'),
#   ('http://news.seoul.go.kr/citybuild/archives/501549',
#    20810,
#    '2019년 도시(재생) 및 건축 분야 용역 설명회',
#    ('2019-01-09', '16:15:26'),
#    '주택',
#    '일 시 : 2019. 1. 29.(화) 15:00~17:00\n장 소 : 서울시청 서소문청사 13층 대회의실'),
#   ('http://news.seoul.go.kr/safe/archives/500376',
#    20809,
#    '市, 서울소방 사상최초 여성소방서장 탄생하다.',
#    ('2019-01-09', '15:47:55'),
#    '안전',
#    '서울시는 서울소방 역사상 최초로 여성소방공무원인 이원주(56세) 서울소방학교 교육지원과장을 2019년 1월 9일자로 일선 소방현장 지휘관인 중랑소방서장으로 발령했다고 밝혔다.'),
#   ('http://news.seoul.go.kr/traffic/archives/500489',
#    20808,
#    '현금.카드 꺼낼필요 없어요! 서울시 ‘지갑 없는 자동결제 주차장’구축',
#    ('2019-01-09', '15:43:39'),
#    '교통',
#    '9월 공영주차장 7곳 자동결제 시범적용, ´20년 8월까지 109곳으로 확대'),
#   ('http://news.seoul.go.kr/gov/archives/502140',
#    20807,
#    '서울시, 시민 삶 접점 30개 사업 전 과정 시민과 협치…77억 투입',
#    ('2019-01-09', '15:36:58'),
#    '행정',
#    '시, 시민참여예산-시정협치형 30개 사업 77억 8천 편성, 전년 대비 83% 증가')]]
